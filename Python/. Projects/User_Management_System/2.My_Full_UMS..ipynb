# %%
import random


class User_Model:
    # User Model
    """ Where every logic is written and database is maintained."""

    # This is a list a.k.a a main database where dictionary in added. In each dictionary, there is the information of user.
    users_database = []

    def create_user_query(self, user_input_dictionary): #..................................question_6
        # Adding to the list.
        print('create_user_query ==> append into database')
        self.users_database.append(user_input_dictionary)

    def add_user_query(self, add_info):
        # Creating a method where user can add.
        
        if add_info == 1:
            user_name = str(input("Enter your User Name:")) # self kin chiyo sabaima ? question_6
            for dictionaries in self.users_database:
                for key, value in dictionaries.items():
                    if key=="User Name" and value==user_name:
                        add_first_name = str(input("Enter first name to add:"))
                        add_dictionary = {"First Name": add_first_name}
                        dictionaries.update(add_dictionary)
                        print("Successful Added")
                        
        elif add_info == 2:
            user_name = str(input("Enter your User Name:"))# answer vetepaxi pani loop run vairakhxa so we need to break it??? question_5
            for dictionaries in self.users_database:
                result=False
                for key, value in dictionaries.items():
                    if key == "User Name" and value == user_name:
                        add_last_name = str(input("Enter last name to add:"))
                        add_dictionary = {"Last Name": add_last_name}
                        dictionaries.update(add_dictionary)
                        print("Successful Added")
                        result = True
                        break
                if result:
                    break
                        
        elif add_info == 3:
            user_name = str(input("Enter your User Name:"))
            for dictionaries in self.users_database:
                for key, value in dictionaries.items():
                    if key=="User Name" and value==user_name:
                        add_email = str(input("Enter email id to add:"))
                        add_dictionary = {"Email Id": add_email}
                        dictionaries.update(add_dictionary)
                        print("Successful Added")
                        
        elif add_info == 4:
            user_name = str(input("Enter your User Name:"))
            for dictionaries in self.users_database:
                for key, value in dictionaries.items():
                    if key=="User Name" and value==user_name:
                        add_password = str(input("Enter password to add:"))
                        add_dictionary = {"First Name": add_password}
                        dictionaries.update(add_dictionary)
                        print("Successful Added")
        else:
            print("Enter number from 1 to 4")

            
            
    def update_user_query(self, update_info):
        # Creating a method where user can update their information.
        
        if update_info == 1:
            user_name = str(input("Enter your User Name:"))
            for dictionaries in self.users_database:
                for key, value in dictionaries.items():
                    if key == "User Name" and value == user_name:
                        updated_user_name = str(input("Enter new user name to update:"))
                        updated_dictionary = {"User Name": updated_user_name}
                        dictionaries.update(updated_dictionary)
                        print("Successful Updated")
                        
        elif update_info == 2:
            user_name = str(input("Enter your User Name:"))
            for dictionaries in self.users_database:
                for key, value in dictionaries.items():
                    if key == "User Name" and value == user_name:
                        updated_first_name = str(input("Enter new first name to update:"))
                        updated_dictionary = {"First Name": updated_first_name}
                        dictionaries.update(updated_dictionary)
                        print("Successful Updated")
                        
        elif update_info == 3:
            user_name = str(input("Enter your User Name:"))
            for dictionaries in self.users_database:
                for key, value in dictionaries.items():
                    if key == "User Name" and value == user_name:
                        updated_last_name = str(input("Enter new last name to update:"))
                        updated_dictionary = {"Last Name": updated_last_name}
                        dictionaries.update(updated_dictionary)
                        print("Successful Updated")
                        
        elif update_info == 4:
            user_name = str(input("Enter your User Name:"))
            for dictionaries in self.users_database:
                for key, value in dictionaries.items():
                    if key == "User Name" and value == user_name:
                        updated_email = str(input("Enter new email to update:"))
                        updated_dictionary = {"Email Id": updated_email}
                        dictionaries.update(updated_dictionary)
                        print("Successful Updated")
                        
        elif update_info == 5:
            user_name = str(input("Enter your User Name:"))
            for dictionaries in self.users_database:
                for key, value in dictionaries.items():
                    if key == "User Name" and value == user_name:
                        updated_password = str(input("Enter new password to update:"))
                        updated_dictionary = {"Password": updated_password}
                        dictionaries.update(updated_dictionary)
                        print("Successful Updated")
                        
        else:
            print("Enter number from 1 to 4")

            
    def delete_user_query(self, delete_info):
        
        # creating a delete method so that users can delete their information.
        if delete_info == 1:
            first_name = str(input("Enter your First Name to delete:")) 
            for dictionaries in self.users_database:
                for key, value in dictionaries.items():
                    if key == "First Name" and value == first_name:
                        del dictionaries["First Name"]
                        print("Successful Deleted")
                        break
                        
        elif delete_info == 2:
            lastname = str(input("Enter your Last Name to delete:"))# delete first name tara kun user name yo code  le sabai entered like firstname delete garxa??? question_4
            for dictionaries in self.users_database:
                for key, value in dictionaries.items():
                    if key == "Last Name" and value == lastname:
                        del dictionaries["Last Name"]
                        print("Successful Deleted")
                        break
                        
        elif delete_info == 3:
            email = input("Enter your Email to delete:")
            for dictionaries in self.users_database:
                for key, value in dictionaries.items():
                    if key == "Email Id" and value == email:
                        del dictionaries["Email Id"]
                        print("Successful Deleted")
                        break
                        
        elif delete_info == 4:
            password = input("Enter your password to delete:")
            for dictionaries in self.users_database:
                for key, value in dictionaries.items():
                    if key == "Password" and value == password:
                        del dictionaries["Password"]
                        print("Successful Deleted")
                        break
                        
        else:
            print("Enter number from 1 to 4")

            
    def retrieve_user_query(self, show_your_info):
        # creating a method so that users can retrieve their information and see.
        for dictionaries in self.users_database:
            for key, value in dictionaries.items():
                if key == "User Name" and value == show_your_info:
                    print(dictionaries)
   

    def view_all_users(self):
        print(self.users_database)
    # difference between view_retrieve(veiw current instance user) and view_all_user(veiw all user in database)  question_6
        
        
class User_View(User_Model):

    # creating a class user view to show the function to the users so that they can take action on it.

    def view_menu_for_admin(self):
        print("""
        Menus
        Enter number 1 to 6 to do the following task:
        1. Create User
        2. Add User
        3. Update User
        4. Delete User 
        5. Retrieve User
        6. View All Users
        """)

    def view_menu_for_user(self):
        print("""
        Menus
        Enter number 1 to 4 to do the following task:
        1. Create User
        2. Add User
        3. Update User
        4. Retrieve User
        """)

    def view_create(self):
        print('Method View_Create !!!!!! ')
        user_id1 = random.randrange(1000)
        user_name = str(input("Enter your user name:"))
        first_name = str(input("Enter your first name:"))
        last_name = str(input("Enter your last name:"))
        email_id = input("Enter your email id:")
        password = input("Enter your password:")
            
        #..................................question_3
        user_input_dictionary = {
        "User Id": user_id1,
        "User Name": user_name,
        "First Name": first_name,
        "Last Name": last_name,
        "Email Id": email_id,
        "Password": password}
        super().create_user_query(user_input_dictionary) #..................................question_3

    def view_add(self):
            print("""
            Enter the following number to add the information:            
            1. Add First Name
            2. Add Last Name
            3. Add Email Id
            4. Add Password
            """)
            add_info = int(input("Enter number here:"))
            super().add_user_query(add_info)

    def view_update(self):
            print("""
             Enter the following number to Update the information:
             1. Update User Name
             2. Update First Name
             3. Update Last Name
             4. Update Email Id
             5. Update Password              
             """)
            update_info = int(input("Enter number here:"))
            super().update_user_query(update_info)

    def view_delete(self):
            print("""
                Enter the following number to delete the  information:
                1. Delete First Name
                2. Delete Last Name
                3. Delete Email Id
                4. Delete Password
                """)
            delete_info = int(input("Enter number here:"))
            super().delete_user_query(delete_info)

    def view_retrieve(self):
            # RetrieveUser from database
            show_your_info = str(input("Enter your user name to retrieve your information:"))
            super().retrieve_user_query(show_your_info)

    def view_all_user(self):
            # view all data
            super().view_all_users()
            #..................................question_7


#..................................question_2


class Permissions_Module(User_View):

    # creating a class permission module so that we can give access to the users
    def admin_role(self):
        while True:

            super().view_menu_for_admin()

            choose_action = int(input("Enter Here:"))
           
            while choose_action > 6 or choose_action < 1:
                choose_action = int(input("Enter only form 1 to 4:")) #.................................. question_1

            if choose_action == 1:

                super().view_create()   #.................................. question_2

            elif choose_action == 2:

                super().view_add()

            elif choose_action == 3:

                super().view_update()

            elif choose_action == 4:

                super().view_delete()

            elif choose_action == 5:

                super().view_retrieve()

            else:
                super().view_all_user()

            answer = str(input("Enter to continue or type c to close:"))
            if answer == "c":
                break


    def user_role(self):

        while True:
            super().view_menu_for_user()

            choose_action = int(input("Enter Here:"))
            
            
            while choose_action > 4 or choose_action < 1:
                choose_action = int(input("Enter only form 1 to 4:")) #.................................. question_1
                
            if choose_action == 1:
                super().create_user_controller()
            elif choose_action == 2:
                super().view_add()
            elif choose_action == 3:
                super().view_update()
            elif choose_action == 4:
                super().view_retrieve()

            answer = str(input("Enter to continue or type c to close:"))
            if answer == "c":
                break




class Role_Model(Permissions_Module):

    # creating a class so that we can assign roll for the users.

    def choose_role(self):
        while True:
            print("""
            Enter number to choose the following role:
            1. Admin
            2. User
            """)
            user_role = int(input("Enter Here:"))
            if user_role == 1:
                super().admin_role()
            else:
                super().user_role()

            answer = str(input("Enter to continue or type c to close:"))
            if answer == "c":
                break

obj_for_role = Role_Model()
obj_for_role.choose_role()
# print(User_Model.users_database)
# Out:
#             Enter number to choose the following role:
#             1. Admin
#             2. User
#
# Enter Here:1
#
#         Menus
#         Enter number 1 to 6 to do the following task:
#         1. Create User
#         2. Add User
#         3. Update User
#         4. Delete User
#         5. Retrieve User
#         6. View All Users
#
# Enter Here:2
#
#             Enter the following number to add the information:
#             1. Add First Name
#             2. Add Last Name
#             3. Add Email Id
#             4. Add Password
#
# Enter number here:2
# Enter your User Name:a
# Enter to continue or type c to close:
#
#         Menus
#         Enter number 1 to 6 to do the following task:
#         1. Create User
#         2. Add User
#         3. Update User
#         4. Delete User
#         5. Retrieve User
#         6. View All Users
#
# Enter Here:6
# []
# Enter to continue or type c to close:
#
#         Menus
#         Enter number 1 to 6 to do the following task:
#         1. Create User
#         2. Add User
#         3. Update User
#         4. Delete User
#         5. Retrieve User
#         6. View All Users
#
# Enter Here:1
# Method View_Create !!!!!!
# Enter your user name:A
# Enter your first name:s
# Enter your last name:d
# Enter your email id:f
# Enter your password:g
# create_user_query ==> append into database
# Enter to continue or type c to close:
#
#         Menus
#         Enter number 1 to 6 to do the following task:
#         1. Create User
#         2. Add User
#         3. Update User
#         4. Delete User
#         5. Retrieve User
#         6. View All Users
#
# Enter Here:6
# [{'User Id': 280, 'User Name': 'A', 'First Name': 's', 'Last Name': 'd', 'Email Id': 'f', 'Password': 'g'}]
# Enter to continue or type c to close:
#
#         Menus
#         Enter number 1 to 6 to do the following task:
#         1. Create User
#         2. Add User
#         3. Update User
#         4. Delete User
#         5. Retrieve User
#         6. View All Users
#
# Enter Here:2
#
#             Enter the following number to add the information:
#             1. Add First Name
#             2. Add Last Name
#             3. Add Email Id
#             4. Add Password
#
# Enter number here:2
# Enter your User Name:A
# Enter last name to add:asdasdasd
# Successful Added
# Enter to continue or type c to close:
#
#         Menus
#         Enter number 1 to 6 to do the following task:
#         1. Create User
#         2. Add User
#         3. Update User
#         4. Delete User
#         5. Retrieve User
#         6. View All Users
#
# Enter Here:6
# [{'User Id': 280, 'User Name': 'A', 'First Name': 's', 'Last Name': 'asdasdasd', 'Email Id': 'f', 'Password': 'g'}]
# Enter to continue or type c to close:c
# Enter to continue or type c to close:c
