# %%
user_dictionary={}
user_list=[]

class User_Model:

    def dictionary_fake(self):
        user_dictionary['id']=self.user_id
        user_dictionary['name']=self.username # here it override the previous key:vale of dictionary of list
        user_dictionary['email']=self.email
            
    def database_fake(self):
        user_list.append(user_dictionary)
    
    def dict_show(self):
        print(user_dictionary)
    
    def list_show(self):
        print(user_list)
        
        
class User_Controller(User_Model):
    
    def AddUser(self):
        self.user_id = input('Enter Id : ')
        self.username = input('Enter Name : ')
        self.email = input('Enter Email : ')


person_1=User_Controller()
person_1.AddUser()
person_2.list_show()
person_1.dictionary_fake()
print('Info Add To Dictionary')
person_2.list_show()
person_1.database_fake()
print('Info Add To List')
person_1.dict_show()
person_1.list_show()

person_2 = User_Controller()
person_2.AddUser()
person_2.list_show()
person_2.dictionary_fake()
print('Info Add To Dictionary')
person_2.list_show()
person_2.database_fake()
print('Info Add To List')
person_2.dict_show()
person_2.list_show()

person_3 = User_Controller()
person_3.AddUser()
person_2.list_show()
person_3.dictionary_fake()
print('Info Add To Dictionary')
person_2.list_show()
person_3.database_fake()
print('Info Add To List')
person_3.dict_show()
person_3.list_show()
# Out:
# Enter Id : 1
# Enter Name : 2
# Enter Email : 3
# []
# Info Add To Dictionary
# []
# Info Add To List
# {'id': '1', 'name': '2', 'email': '3'}
# [{'id': '1', 'name': '2', 'email': '3'}]
# Enter Id : 4
# Enter Name : 5
# Enter Email : 6
# [{'id': '1', 'name': '2', 'email': '3'}]
# Info Add To Dictionary
# [{'id': '4', 'name': '5', 'email': '6'}]
# Info Add To List
# {'id': '4', 'name': '5', 'email': '6'}
# [{'id': '4', 'name': '5', 'email': '6'}, {'id': '4', 'name': '5', 'email': '6'}]
# Enter Id : 7
# Enter Name : 8
# Enter Email : 9
# [{'id': '4', 'name': '5', 'email': '6'}, {'id': '4', 'name': '5', 'email': '6'}]
# Info Add To Dictionary
# [{'id': '7', 'name': '8', 'email': '9'}, {'id': '7', 'name': '8', 'email': '9'}]
# Info Add To List
# {'id': '7', 'name': '8', 'email': '9'}
# [{'id': '7', 'name': '8', 'email': '9'}, {'id': '7', 'name': '8', 'email': '9'}, {'id': '7', 'name': '8', 'email': '9'}]

# %%
user_list=[]

class User_Model:
    
    user_dictionary={}
    
    def dictionary_fake(self):
        self.user_dictionary['id']=self.user_id
        self.user_dictionary['name']=self.username # here it override the previous key:vale of dictionary of list
        self.user_dictionary['email']=self.email
            
    def database_fake(self):
        user_list.append(self.user_dictionary)
    
    def dict_show(self):
        print(self.user_dictionary)
    
    def list_show(self):
        print(user_list)
        
        
class User_Controller(User_Model):
    
    def AddUser(self):
        self.user_id = input('Enter Id : ')
        self.username = input('Enter Name : ')
        self.email = input('Enter Email : ')


person_1=User_Controller()
person_1.AddUser()
person_1.list_show()
person_1.dictionary_fake()
print('Info Add To Dictionary')
person_1.list_show()
person_1.database_fake()
print('Info Add To List')
person_1.dict_show()
person_1.list_show()

person_2 = User_Controller()
person_2.AddUser()
person_2.list_show()
person_2.dictionary_fake()
print('Info Add To Dictionary')
person_2.list_show()
person_2.database_fake()
print('Info Add To List')
person_2.dict_show()
person_2.list_show()

person_3 = User_Controller()
person_3.AddUser()
person_3.list_show()
person_3.dictionary_fake()
print('Info Add To Dictionary')
person_3.list_show()
person_3.database_fake()
print('Info Add To List')
person_3.dict_show()
person_3.list_show()
# Out:
# Enter Id : 1
# Enter Name : 2
# Enter Email : 3
# []
# Info Add To Dictionary
# []
# Info Add To List
# {'id': '1', 'name': '2', 'email': '3'}
# [{'id': '1', 'name': '2', 'email': '3'}]
# Enter Id : 4
# Enter Name : 5
# Enter Email : 6
# [{'id': '1', 'name': '2', 'email': '3'}]
# Info Add To Dictionary
# [{'id': '4', 'name': '5', 'email': '6'}]
# Info Add To List
# {'id': '4', 'name': '5', 'email': '6'}
# [{'id': '4', 'name': '5', 'email': '6'}, {'id': '4', 'name': '5', 'email': '6'}]
# Enter Id : 7
# Enter Name : 8
# Enter Email : 9
# [{'id': '4', 'name': '5', 'email': '6'}, {'id': '4', 'name': '5', 'email': '6'}]
# Info Add To Dictionary
# [{'id': '7', 'name': '8', 'email': '9'}, {'id': '7', 'name': '8', 'email': '9'}]
# Info Add To List
# {'id': '7', 'name': '8', 'email': '9'}
# [{'id': '7', 'name': '8', 'email': '9'}, {'id': '7', 'name': '8', 'email': '9'}, {'id': '7', 'name': '8', 'email': '9'}]

# %%
user_list=[]

class User_Model:
    
    def dictionary_fake(self):
        self.user_dictionary={}
        self.user_dictionary['id']=self.user_id
        self.user_dictionary['name']=self.username
        self.user_dictionary['email']=self.email
            
    def database_fake(self):
        user_list.append(self.user_dictionary)
    
    def dict_show(self):
        print(self.user_dictionary)
    
    def list_show(self):
        print(user_list)
        
        
class User_Controller(User_Model):
    
    def AddUser(self):
        self.user_id = input('Enter Id : ')
        self.username = input('Enter Name : ')
        self.email = input('Enter Email : ')


person_1=User_Controller()
person_1.AddUser()
person_1.list_show()
person_1.dictionary_fake()
print('Info Add To Dictionary')
person_1.list_show()
person_1.database_fake()
print('Info Add To List')
person_1.dict_show()
person_1.list_show()

person_2 = User_Controller()
person_2.AddUser()
person_2.list_show()
person_2.dictionary_fake()
print('Info Add To Dictionary')
person_2.list_show()
person_2.database_fake()
print('Info Add To List')
person_2.dict_show()
person_2.list_show()

person_3 = User_Controller()
person_3.AddUser()
person_3.list_show()
person_3.dictionary_fake()
print('Info Add To Dictionary')
person_3.list_show()
person_3.database_fake()
print('Info Add To List')
person_3.dict_show()
person_3.list_show()
# Out:
# Enter Id : 1
# Enter Name : amir
# Enter Email : a.com
# []
# Info Add To Dictionary
# []
# Info Add To List
# {'id': '1', 'name': 'amir', 'email': 'a.com'}
# [{'id': '1', 'name': 'amir', 'email': 'a.com'}]
# Enter Id : 2
# Enter Name : riyana
# Enter Email : r.com
# [{'id': '1', 'name': 'amir', 'email': 'a.com'}]
# Info Add To Dictionary
# [{'id': '1', 'name': 'amir', 'email': 'a.com'}]
# Info Add To List
# {'id': '2', 'name': 'riyana', 'email': 'r.com'}
# [{'id': '1', 'name': 'amir', 'email': 'a.com'}, {'id': '2', 'name': 'riyana', 'email': 'r.com'}]
# Enter Id : 3
# Enter Name : jini
# Enter Email : j.com
# [{'id': '1', 'name': 'amir', 'email': 'a.com'}, {'id': '2', 'name': 'riyana', 'email': 'r.com'}]
# Info Add To Dictionary
# [{'id': '1', 'name': 'amir', 'email': 'a.com'}, {'id': '2', 'name': 'riyana', 'email': 'r.com'}]
# Info Add To List
# {'id': '3', 'name': 'jini', 'email': 'j.com'}
# [{'id': '1', 'name': 'amir', 'email': 'a.com'}, {'id': '2', 'name': 'riyana', 'email': 'r.com'}, {'id': '3', 'name': 'jini', 'email': 'j.com'}]

# %%
user_list=[]

class User_Model:
    
    def dictionary_fake(self):
        self.user_dictionary={}
        self.user_dictionary['id']=self.user_id
        self.user_dictionary['name']=self.username
        self.user_dictionary['email']=self.email
            
    def database_fake(self):
        user_list.append(self.user_dictionary)
    
    def dict_show(self):
        print(self.user_dictionary)
    
    def list_show(self):
        print(user_list)
        
        
class User_Controller(User_Model):
    
    def AddUser(self):
        self.user_id = input('Enter Id : ')
        self.username = input('Enter Name : ')
        self.email = input('Enter Email : ')

        
        
#     def __init__():
#         pass


    def UpdateUser(self,idd):
        if idd in self.user_dictionary['id']:
            new_name=input('Update Name : ')
            for iid = self.user_dictionary['id']:
                user_dictionary['name'].update(new_name)
        
    def DeleteUser():
        pass

    def RetrieveUser():
        pass

        
        
        

person_1=User_Controller()
person_1.AddUser()
person_1.list_show()
person_1.dictionary_fake()
print('Info Add To Dictionary')
person_1.list_show()
person_1.database_fake()
print('Info Add To List')
person_1.dict_show()
person_1.list_show()

person_2 = User_Controller()
person_2.AddUser()
person_2.list_show()
person_2.dictionary_fake()
print('Info Add To Dictionary')
person_2.list_show()
person_2.database_fake()
print('Info Add To List')
person_2.dict_show()
person_2.list_show()

person_3 = User_Controller()
person_3.AddUser()
person_3.list_show()
person_3.dictionary_fake()
print('Info Add To Dictionary')
person_3.list_show()
person_3.database_fake()
print('Info Add To List')
person_3.dict_show()
person_3.list_show()
# Out:
#   File "<ipython-input-5-08dd34052d3a>", line 37
#     for iid = self.user_dictionary['id']:
#             ^
# SyntaxError: invalid syntax
